# %%
#pip install bs4

# %%
#pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://www.imdb.com/chart/top/'

# %%
permission=requests.get(url)

# %%
permission
# Out:
# <Response [200]>

# %%
text=BeautifulSoup(permission.text)

# %%
text
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top 250 Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/chart/top/" rel="canonical"/>
# <meta content="http://www.imdb.com/chart/top/" property="og:url"/>
# <script>
# ...

# %%
movie_name=text.select('.titleColumn a')

# %%
movie_name
# Out:
# [<a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>,
#  <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>,
#  <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>,
#  <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather Part II</a>,
#  <a href="/title/tt0050083/" title="Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb">12 Angry Men</a>,
#  <a href="/title/tt0108052/" title="Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes">Schindler's List</a>,
#  <a href="/title/tt0167260/" title="Peter Jackson (dir.), Elijah Wood, Viggo Mortensen">The Lord of the Rings: The Return of the King</a>,
#  <a href="/title/tt0110912/" title="Quentin Tarantino (dir.), John Travolta, Uma Thurman">Pulp Fiction</a>,
# ...

# %%
movie_year=text.select('.secondaryInfo')

# %%
movie_year
# Out:
# [<span class="secondaryInfo">(1994)</span>,
#  <span class="secondaryInfo">(1972)</span>,
#  <span class="secondaryInfo">(2008)</span>,
#  <span class="secondaryInfo">(1974)</span>,
#  <span class="secondaryInfo">(1957)</span>,
#  <span class="secondaryInfo">(1993)</span>,
#  <span class="secondaryInfo">(2003)</span>,
#  <span class="secondaryInfo">(1994)</span>,
#  <span class="secondaryInfo">(2001)</span>,
#  <span class="secondaryInfo">(1966)</span>,
#  <span class="secondaryInfo">(1994)</span>,
#  <span class="secondaryInfo">(1999)</span>,
#  <span class="secondaryInfo">(2002)</span>,
#  <span class="secondaryInfo">(2010)</span>,
#  <span class="secondaryInfo">(1980)</span>,
#  <span class="secondaryInfo">(1999)</span>,
#  <span class="secondaryInfo">(1990)</span>,
#  <span class="secondaryInfo">(1975)</span>,
#  <span class="secondaryInfo">(1995)</span>,
#  <span class="secondaryInfo">(1954)</span>,
#  <span class="secondaryInfo">(1946)</span>,
# ...

# %%
movie_ratings=text.select('strong')

# %%
movie_ratings
# Out:
# [<strong title="9.2 based on 2,721,317 user ratings">9.2</strong>,
#  <strong title="9.2 based on 1,891,189 user ratings">9.2</strong>,
#  <strong title="9.0 based on 2,694,153 user ratings">9.0</strong>,
#  <strong title="9.0 based on 1,290,248 user ratings">9.0</strong>,
#  <strong title="9.0 based on 804,462 user ratings">9.0</strong>,
#  <strong title="8.9 based on 1,374,463 user ratings">8.9</strong>,
#  <strong title="8.9 based on 1,872,395 user ratings">8.9</strong>,
#  <strong title="8.8 based on 2,090,068 user ratings">8.8</strong>,
#  <strong title="8.8 based on 1,901,583 user ratings">8.8</strong>,
#  <strong title="8.8 based on 771,676 user ratings">8.8</strong>,
#  <strong title="8.8 based on 2,115,950 user ratings">8.8</strong>,
#  <strong title="8.7 based on 2,164,733 user ratings">8.7</strong>,
#  <strong title="8.7 based on 1,690,378 user ratings">8.7</strong>,
#  <strong title="8.7 based on 2,391,007 user ratings">8.7</strong>,
# ...

# %%
movie_heading=text.select('#sidebar a')

# %%
import pandas as pds

# %%
import numpy as num

# %%
movies_data=pds.DataFrame(movie_name)

# %%
movies_data
# Out:
#                             0
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3       The Godfather Part II
# 4                12 Angry Men
# ..                        ...
# 245            The Iron Giant
# 246                  The Help
# 247               Dersu Uzala
# 248                   Aladdin
# 249        Dances with Wolves
#
# [250 rows x 1 columns]

# %%
movies_year=pds.DataFrame(movie_year)

# %%
movies_year
# Out:
#           0
# 0    (1994)
# 1    (1972)
# 2    (2008)
# 3    (1974)
# 4    (1957)
# ..      ...
# 245  (1999)
# 246  (2011)
# 247  (1975)
# 248  (1992)
# 249  (1990)
#
# [250 rows x 1 columns]

# %%
movies_data["year"]=movies_year

# %%
movies_data
# Out:
#                             0    year
# 0    The Shawshank Redemption  (1994)
# 1               The Godfather  (1972)
# 2             The Dark Knight  (2008)
# 3       The Godfather Part II  (1974)
# 4                12 Angry Men  (1957)
# ..                        ...     ...
# 245            The Iron Giant  (1999)
# 246                  The Help  (2011)
# 247               Dersu Uzala  (1975)
# 248                   Aladdin  (1992)
# 249        Dances with Wolves  (1990)
#
# [250 rows x 2 columns]

# %%
movies=pds.DataFrame({'movie_name':movie_name,'movie_year':movie_year,'movie_ratings':movie_ratings})

# %%
movies
# Out:
#                      movie_name movie_year movie_ratings
# 0    [The Shawshank Redemption]   [(1994)]         [9.2]
# 1               [The Godfather]   [(1972)]         [9.2]
# 2             [The Dark Knight]   [(2008)]         [9.0]
# 3       [The Godfather Part II]   [(1974)]         [9.0]
# 4                [12 Angry Men]   [(1957)]         [9.0]
# ..                          ...        ...           ...
# 245            [The Iron Giant]   [(1999)]         [8.0]
# 246                  [The Help]   [(2011)]         [8.0]
# 247               [Dersu Uzala]   [(1975)]         [8.0]
# 248                   [Aladdin]   [(1992)]         [8.0]
# 249        [Dances with Wolves]   [(1990)]         [8.0]
#
# [250 rows x 3 columns]

# %%
imdb=movies.to_csv('C:/scl/IMDB data.csv')

# %%
d=movies_data.to_csv('C:/scl/mo.csv')

# %% [markdown]
# ### webscarpping

# %%
url='https://www.imdb.com/list/ls058654847/'

# %%
perm=requests.get(url)

# %%
perm
# Out:
# <Response [200]>

# %%
Text=BeautifulSoup(perm.text)

# %%
Text
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top Anime Series Of All-Time - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls058654847/" rel="canonical"/>
# ...

# %%
series_name=Text.select('.lister-item-header a')

# %%
series_name
# Out:
# [<a href="/title/tt1355642/">Hagane no renkinjutsushi</a>,
#  <a href="/title/tt2098220/">Hunter x Hunter</a>,
#  <a href="/title/tt1910272/">Steins;Gate</a>,
#  <a href="/title/tt1298820/">Clannad: After Story</a>,
#  <a href="/title/tt0994314/">Code Geass: Hangyaku no Lelouch</a>,
#  <a href="/title/tt0213338/">Kaubôi bibappu: Cowboy Bebop</a>,
#  <a href="/title/tt0481256/">Hajime no ippo</a>,
#  <a href="/title/tt0948103/">Tengen toppa gurren lagann</a>,
#  <a href="/title/tt0877057/">Death Note: Desu nôto</a>,
#  <a href="/title/tt0434706/">Monster</a>,
#  <a href="/title/tt0807832/">Mushishi</a>,
#  <a href="/title/tt0988818/">Gintama</a>,
#  <a href="/title/tt0096633/">Ginga Eiyuu Densetsu</a>,
#  <a href="/title/tt0315008/">GTO</a>,
#  <a href="/title/tt2560140/">Shingeki no Kyojin</a>,
#  <a href="/title/tt1992744/">Hajime no Ippo: New Challenger</a>,
#  <a href="/title/tt1913273/">Ano hi mita hana no namae o bokutachi wa mada shiranai.</a>,
# ...

# %%
series=pds.DataFrame({'series':series_name})

# %%
# Out:
#                                series
# 0          [Hagane no renkinjutsushi]
# 1                   [Hunter x Hunter]
# 2                       [Steins;Gate]
# 3              [Clannad: After Story]
# 4   [Code Geass: Hangyaku no Lelouch]
# ..                                ...
# 95          [Serial Experiments Lain]
# 96                  [Bleach: Burîchi]
# 97                       [Last Exile]
# 98                      [Erufen rîto]
# 99                      [Wolf's Rain]
#
# [100 rows x 1 columns]

# %%
series['series_name']=series_name

# %%
seriesd=
# Out:
#                                series                        series_name
# 0          [Hagane no renkinjutsushi]         [Hagane no renkinjutsushi]
# 1                   [Hunter x Hunter]                  [Hunter x Hunter]
# 2                       [Steins;Gate]                      [Steins;Gate]
# 3              [Clannad: After Story]             [Clannad: After Story]
# 4   [Code Geass: Hangyaku no Lelouch]  [Code Geass: Hangyaku no Lelouch]
# ..                                ...                                ...
# 95          [Serial Experiments Lain]          [Serial Experiments Lain]
# 96                  [Bleach: Burîchi]                  [Bleach: Burîchi]
# 97                       [Last Exile]                       [Last Exile]
# 98                      [Erufen rîto]                      [Erufen rîto]
# 99                      [Wolf's Rain]                      [Wolf's Rain]
#
# [100 rows x 2 columns]

# %%
d=pds.DataFrame(series)

# %%
d
# Out:
#                                series                        series_name
# 0          [Hagane no renkinjutsushi]         [Hagane no renkinjutsushi]
# 1                   [Hunter x Hunter]                  [Hunter x Hunter]
# 2                       [Steins;Gate]                      [Steins;Gate]
# 3              [Clannad: After Story]             [Clannad: After Story]
# 4   [Code Geass: Hangyaku no Lelouch]  [Code Geass: Hangyaku no Lelouch]
# ..                                ...                                ...
# 95          [Serial Experiments Lain]          [Serial Experiments Lain]
# 96                  [Bleach: Burîchi]                  [Bleach: Burîchi]
# 97                       [Last Exile]                       [Last Exile]
# 98                      [Erufen rîto]                      [Erufen rîto]
# 99                      [Wolf's Rain]                      [Wolf's Rain]
#
# [100 rows x 2 columns]

# %%
d.to_csv('C:/scl/series.csv')
